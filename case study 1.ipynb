# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('startup_funding.csv')
df=data.copy()
df.SubVertical.fillna('SubVertical', inplace=True)
df.tail()
# Out:
#        SNo        Date       StartupName IndustryVertical  SubVertical  \
# 2367  2367  29-01-2015        Printvenue              NaN  SubVertical
# 2368  2368  29-01-2015          Graphene              NaN  SubVertical
# 2369  2369  30-01-2015    Mad Street Den              NaN  SubVertical
# 2370  2370  30-01-2015         Simplotel              NaN  SubVertical
# 2371  2371  31-01-2015  couponmachine.in              NaN  SubVertical
#
#      CityLocation                      InvestorsName  InvestmentType  \
# 2367          NaN        Asia Pacific Internet Group  Private Equity
# 2368          NaN                     KARSEMVEN Fund  Private Equity
# 2369          NaN     Exfinity Fund, GrowX Ventures.  Private Equity
# 2370          NaN                         MakeMyTrip  Private Equity
# 2371          NaN  UK based Group of Angel Investors    Seed Funding
#
#      AmountInUSD                            Remarks
# 2367   45,00,000                                NaN
# ...
