# %%
import pandas as pd
import numpy as np

# %%
iris = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')
print(iris)
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
print(type(iris))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df = iris.copy()

# %%
df.columns = ['sepal.length','sepal.width','petal.length','petal.width','variety']
df.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width      variety
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa

# %%
print(df.shape)
print(df.dtypes)
# Out:
# (149, 5)
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.848322     3.051007      3.774497     1.205369
# std        0.828594     0.433499      1.759651     0.761292
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.columns = ['sepal_length','sepal_width','petal_length','petal_width','variety']
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'variety'],
#       dtype='object')

# %%
df.sepal_length
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
#       ...
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sepal_length, Length: 149, dtype: float64

# %%
df.columns = ['sepal.length','sepal.width','petal.length','petal.width','variety']
df.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
df["sepal.length"]
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
#       ...
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sepal.length, Length: 149, dtype: float64

# %%
df.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
df.iloc[1:9,2:4]
# Out:
#    petal.length  petal.width
# 1           1.3          0.2
# 2           1.5          0.2
# 3           1.4          0.2
# 4           1.7          0.4
# 5           1.4          0.3
# 6           1.5          0.2
# 7           1.4          0.2
# 8           1.5          0.1

# %%
df.drop(1, inplace = True)
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width      variety
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa
# 5           4.6          3.4           1.4          0.3  Iris-setosa

# %%
df.index
# Out:
# Int64Index([  0,   2,   3,   4,   5,   6,   7,   8,   9,  10,
#             ...
#             139, 140, 141, 142, 143, 144, 145, 146, 147, 148],
#            dtype='int64', length=148)

# %%
df.drop(df.index[[0,1]], inplace= True)
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width      variety
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa
# 5           4.6          3.4           1.4          0.3  Iris-setosa
# 6           5.0          3.4           1.5          0.2  Iris-setosa
# 7           4.4          2.9           1.4          0.2  Iris-setosa

# %%
df.drop(df.index[[0,1]], inplace= True)
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width      variety
# 5           4.6          3.4           1.4          0.3  Iris-setosa
# 6           5.0          3.4           1.5          0.2  Iris-setosa
# 7           4.4          2.9           1.4          0.2  Iris-setosa
# 8           4.9          3.1           1.5          0.1  Iris-setosa
# 9           5.4          3.7           1.5          0.2  Iris-setosa

# %%
df.drop(df.index[[0,2]], inplace= True)
df.head()
# Out:
#     sepal.length  sepal.width  petal.length  petal.width      variety
# 6            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.9          3.1           1.5          0.1  Iris-setosa
# 9            5.4          3.7           1.5          0.2  Iris-setosa
# 10           4.8          3.4           1.6          0.2  Iris-setosa
# 11           4.8          3.0           1.4          0.1  Iris-setosa

# %%
df.drop(df.index[0], inplace= True)
df.drop(df.index[[0,1]], inplace= True)
df.head()
# Out:
#     sepal.length  sepal.width  petal.length  petal.width      variety
# 10           4.8          3.4           1.6          0.2  Iris-setosa
# 11           4.8          3.0           1.4          0.1  Iris-setosa
# 12           4.3          3.0           1.1          0.1  Iris-setosa
# 13           5.8          4.0           1.2          0.2  Iris-setosa
# 14           5.7          4.4           1.5          0.4  Iris-setosa

# %%
df["sepal_length"]>3
# Out:
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
#        ...
# 144    True
# 145    True
# 146    True
# 147    True
# 148    True
# Name: sepal_length, Length: 139, dtype: bool

# %%
df.columns = ['sepal_length','sepal_width','petal_length','petal_width','variety']
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'variety'],
#       dtype='object')

# %%
df.sepal_length.sum()
# Out:
# 822.5

# %%
df.petal_length.sum()
# Out:
# 547.8

# %%
df.sepal_width.sum()
# Out:
# 421.30000000000007

# %%
df.sepal_width > 3
# Out:
# 11     False
# 12     False
# 13      True
# 14      True
# 15      True
#        ...
# 144    False
# 145    False
# 146    False
# 147     True
# 148    False
# Name: sepal_width, Length: 138, dtype: bool

# %%
df[df.sepal_length > 3]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         variety
# 10            4.8          3.4           1.6          0.2     Iris-setosa
# 11            4.8          3.0           1.4          0.1     Iris-setosa
# 12            4.3          3.0           1.1          0.1     Iris-setosa
# 13            5.8          4.0           1.2          0.2     Iris-setosa
# 14            5.7          4.4           1.5          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
#
# [139 rows x 5 columns]

# %%
class1= df[df.variety == 'Iris-setosa'].describe()

# %%
class2= df[df.variety == 'Iris-virginica'].describe()
class2
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %%
class3= df[df.variety == 'Iris-versicolor'].describe()
class3
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# 75%        6.300000     3.000000      4.600000     1.500000
# max        7.000000     3.400000      5.100000     1.800000

# %%
print(df.head())
print(df.iloc[0])
print(df.loc[12])
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      variety
# 10           4.8          3.4           1.6          0.2  Iris-setosa
# 11           4.8          3.0           1.4          0.1  Iris-setosa
# 12           4.3          3.0           1.1          0.1  Iris-setosa
# 13           5.8          4.0           1.2          0.2  Iris-setosa
# 14           5.7          4.4           1.5          0.4  Iris-setosa
# sepal_length            4.8
# sepal_width             3.4
# petal_length            1.6
# petal_width             0.2
# variety         Iris-setosa
# Name: 10, dtype: object
# sepal_length            4.3
# sepal_width               3
# petal_length            1.1
# petal_width             0.1
# variety         Iris-setosa
# Name: 12, dtype: object

# %%
df.loc[0] = [4.5,5.3,2.3,0.9, 'Iris-versicolor']

# %%
df.loc[149] = [4.5,5.3,2.3,0.9, 'Iris-versicolor']

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          variety
# 146           6.5          3.0           5.2          2.0   Iris-virginica
# 147           6.2          3.4           5.4          2.3   Iris-virginica
# 148           5.9          3.0           5.1          1.8   Iris-virginica
# 0             4.5          5.3           2.3          0.9  Iris-versicolor
# 149           4.5          5.3           2.3          0.9  Iris-versicolor

# %%
df.reset_index(drop = True , inplace = True)
df.index
# Out:
# RangeIndex(start=0, stop=141, step=1)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          variety
# 0             4.8          3.4           1.6          0.2      Iris-setosa
# 1             4.8          3.0           1.4          0.1      Iris-setosa
# 2             4.3          3.0           1.1          0.1      Iris-setosa
# 3             5.8          4.0           1.2          0.2      Iris-setosa
# 4             5.7          4.4           1.5          0.4      Iris-setosa
# ..            ...          ...           ...          ...              ...
# 136           6.5          3.0           5.2          2.0   Iris-virginica
# 137           6.2          3.4           5.4          2.3   Iris-virginica
# 138           5.9          3.0           5.1          1.8   Iris-virginica
# 139           4.5          5.3           2.3          0.9  Iris-versicolor
# 140           4.5          5.3           2.3          0.9  Iris-versicolor
#
# [141 rows x 5 columns]

# %%
df = iris.copy()
df.columns = ['sepal_length','sepal_width','petal_length','petal_width','variety']
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      variety
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
df["diff_pl_pw"] = df['petal_length'] - df['petal_width']
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         variety  \
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
#
#      diff_pl_pw
# 144         2.9
# 145         3.1
# 146         3.2
# 147         3.1
# 148         3.3

# %%
df.loc[0]
# Out:
# sepal_length            4.9
# sepal_width               3
# petal_length            1.4
# petal_width             0.2
# variety         Iris-setosa
# diff_pl_pw              1.2
# Name: 0, dtype: object

# %%
df.loc[149] = [6,4,5,2,'Iris-setosa',3]

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         variety  \
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
# 149           6.0          4.0           5.0          2.0     Iris-setosa
#
#      diff_pl_pw
# 145         3.1
# 146         3.2
# 147         3.1
# 148         3.3
# 149         3.0

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      variety  \
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa
#
#    diff_pl_pw
# 0         1.2
# 1         1.1
# 2         1.3
# 3         1.2
# 4         1.3

# %%
df.iloc[2:4,1:3] = np.nan
df.iloc[2,3]=0.5
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      variety  \
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          NaN           NaN          0.5  Iris-setosa
# 3           5.0          NaN           NaN          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa
#
#    diff_pl_pw
# 0         1.2
# 1         1.1
# 2         1.3
# 3         1.2
# 4         1.3

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width  diff_pl_pw
# count    150.000000   148.000000    148.000000   150.000000  150.000000
# mean       5.849333     3.053378      3.814189     1.212667    2.572000
# std        0.825902     0.439606      1.747146     0.759220    1.044777
# min        4.300000     2.000000      1.000000     0.100000    0.800000
# 25%        5.100000     2.800000      1.600000     0.300000    1.400000
# 50%        5.800000     3.000000      4.400000     1.300000    2.950000
# 75%        6.400000     3.300000      5.100000     1.800000    3.300000
# max        7.900000     4.400000      6.900000     2.500000    4.700000

# %%
df.dropna(inplace=True)

# %%
df.reset_index(drop = True, inplace = True)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      variety  \
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           5.4          3.9           1.7          0.4  Iris-setosa
# 3           4.6          3.4           1.4          0.3  Iris-setosa
# 4           5.0          3.4           1.5          0.2  Iris-setosa
#
#    diff_pl_pw
# 0         1.2
# 1         1.1
# 2         1.3
# 3         1.1
# 4         1.3

# %%
df.iloc[2:4,1:3] = np.nan
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      variety  \
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           5.4          NaN           NaN          0.4  Iris-setosa
# 3           4.6          NaN           NaN          0.3  Iris-setosa
# 4           5.0          3.4           1.5          0.2  Iris-setosa
#
#    diff_pl_pw
# 0         1.2
# 1         1.1
# 2         1.3
# 3         1.1
# 4         1.3

# %%
df.sepal_width.fillna(df.sepal_width.mean(), inplace = True)
df.petal_length.fillna(df.petal_length.mean(), inplace = True)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      variety  \
# 0           4.9     3.000000      1.400000          0.2  Iris-setosa
# 1           4.7     3.200000      1.300000          0.2  Iris-setosa
# 2           5.4     3.045205      3.845205          0.4  Iris-setosa
# 3           4.6     3.045205      3.845205          0.3  Iris-setosa
# 4           5.0     3.400000      1.500000          0.2  Iris-setosa
#
#    diff_pl_pw
# 0         1.2
# 1         1.1
# 2         1.3
# 3         1.1
# 4         1.3
